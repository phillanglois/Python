# %%
# PhL test des modules
import points
import nuage
import geometrie2d

# %%
p = points.points(10)
#nuag = nuage.nuage(p)
geometrie2d.affiche_enveloppe(p)

# %%
geometrie2d.affiche_enveloppe_nuage(p)

# %%
nuage.lecture("./data_nuage_10.txt")
